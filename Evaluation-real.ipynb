# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from collections import Counter
from datetime import datetime

# %%
df_drugs_train = pd.read_csv("compas-r-drugs-train.csv")
df_drugs_test = pd.read_csv("compas-r-drugs-test.csv")
df_drugs_train_y = df_drugs_train['is_drug_recid']
df_drugs_test_y = df_drugs_test['is_drug_recid']

rs_drugs_3 = {'age_19_24': 1,
             'age_25_29': 1,
             'age_30_34': 1,
             'prior_driving': 1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_drugs_344 = {'age_40_44': -1,
             'age_50_54': -1,
             'age_60_': -1,
             'prior_driving': 1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_drugs_4 = {'priors_11_': 1,
             'prior_driving': 1,
             'priors_6_10': 1,
             'priors_4_5': 1}

rs_drugs_471 = {'age_40_44': -1,
             'age_50_54': -1,
             'age_55_59': -1,
            'age_60_': -1,
             'prior_driving': 2,
             'priors_1': -1,
             'priors_2_3': -1}

rs_drugs_567 = {'age_19_24': 1,
             'age_25_29': 1,
            'age_60_': -1,
             'prior_driving': 1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_drugs_7 = {'age_19_24': 1,
             'age_25_29': 1,
              'age_30_34': 1,
             'prior_driving': 1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_drugs_9 = {'prior_driving': 1,
              'prior_weapons': 1,
              'age_50_54': -1,
              'age_55_59': -1,
                'age_60_': -1,
              'prior_public_order': -1,
             'priors_2_3': -1}

rs_drugs_1233 = {'age_19_24': 1,
             'age_40_44': -1,
              'age_60_': -1,
             'prior_driving': 1,
             'priors_1': -1,
             'priors_2_3': -1}


rs_drugs_19 = {
             'age_40_44': -1,
                 'age_55_59': -1,
              'age_60_': -2,
             'prior_driving': 1,
             'priors_1': -1,
             'priors_2_3': -1,
                'priors_4_5': -1}
# predict "is_drug_recid = +1" if score > 10
s_drugs_3 = {
    'prior_assault': 5,
    'age_30_34': 4,
    'priors_4_5': 4,
    'prior_weapons': 2,
    'juv_fel_count': 1,
    'prior_battery': -1,
    'prior_drugs': -1,
    'prior_felony': -4
}

# predict "is_drug_recid = +1" if score > -1
s_drugs_344 = {
    'juv_misd_1': 4,
    'priors_count': 1,
    'age': -1
}

# predict "is_drug_recid = +1" if score > -1
s_drugs_4 = {
    'priors_count': 1,
    'age': -1
}

#predict "is_drug_recid = +1" if score > 1
s_drugs_471 = {
    'prior_driving': 4,
    'prior_violent': 4,
    'juv_other_1': 4,
    'juv_fel_count': 2,
    'age_35_39': -2,
    'prior_domestic': -2,
    'juv_felony_2_': -2,
    'age_55_59': -4,
    'age_60_': -4,
    'prior_battery': -4,
    'prior_obstruction': -4,
    'prior_agg': -4,
    'priors_1': -4,
    'priors_2_3': -4,
    'juv_other_count': -4,
    'age_50_54': -6,
    'juv_misd_2_': -6,
    'age_40_44': -8,
    'age_45_49': -10
}

# predict "is_drug_recid = +1" if score > 9
s_drugs_567 = {'prior_violent' : 8 ,
'priors_6_10' : 8 ,
'prior_sexual' : 6 ,
'prior_agg' : 6 ,
'priors_11_' : 6 ,
'prior_driving' : 4 ,
'priors_4_5' : 4 ,
'age_19_24' : 2 ,
'age_35_39' : 2 ,
'juv_other_1' : 2 ,
'juv_fel_count' : 2 ,
'age_30_34' : -2,
'prior_battery' : -2,
'prior_drugs' : -2,
'juv_felony_1' : -2,
'juv_misd_1' : -2,
'juv_other_count' : -2,
'prior_weapons' : -4,
'prior_domestic' : -4,
'age_50_54' : -6,
'age_60_' : -6,
'prior_property' : -6,
'prior_obstruction' : -6,
'juv_misd_2_' : -6,
'priors_2_3' : -6,
'priors_1' : -8,
'age_40_44' : -10,
'age_45_49': -10}


# predict "is_drug_recid = +1" if score > -10
s_drugs_7 = {
    'priors_1': 9 ,
'age_45_49': 7 ,
'age_50_54': 6 ,
'prior_weapons': 6 ,
'prior_assault': 4 ,
'prior_driving': 4 ,
'prior_drugs': 4 ,
'priors_4_5': 4 ,
'age_40_44': 3 ,
'juv_other_1': 3 ,
'priors_6_10': 3 ,
'prior_agg': 2 ,
'prior_felony': 2 ,
'priors_count': 2 ,
'juv_other_count': 2 ,
'age_30_34': 1,
'juv_misd_2_': -1 ,
'juv_fel_count': -1,
'age': -1 ,
'prior_battery': -2,
'prior_property': -2,
'juv_misd_count': -2,
'juv_misd_1': -3,
'juv_other_2_': -3,
'age_19_24': -5,
'prior_public_order': -5,
'priors_11_': -8
}
#predict "is_drug_recid = +1" if score > 3
s_drugs_9 = {
'juv_other_1': 10 ,
'juv_other_2_': 10 ,
'priors_11_': 10 ,
'prior_agg': 4  ,
'age_35_39': 2  ,
'prior_assault': 2  ,
'prior_driving': 2  ,
'prior_property': 2  ,
'priors_1': 2  ,
'priors_4_5': 2  ,
'priors_6_10': 2  ,
'age_45_49': -2 ,
'prior_drugs': -2 ,
'prior_weapons': -2 ,
'juv_felony_1': -2 ,
'age_40_44': -4 ,
'prior_sexual': -4 ,
'juv_other_count': -6 ,
'age_50_54': -10,
'age_60_': -10,
'juv_misd_2_': -10
}

#predict "is_drug_recid = +1" if score > -1
s_drugs_1233 = {
    
'juv_misd_2_': 4 ,
'age_19_24': 2 ,
'age_25_29': 2 ,
'priors_11_': 2 ,
'juv_felony_1': 1 ,
'juv_fel_count': -1 ,
'age_50_54': -2,
'prior_battery': -2,
'prior_drugs': -2,
'juv_other_2_': -2,
'priors_1': -2,
'age_35_39': -4,
'age_55_59': -4,
'age_60_': -4,
'priors_2_3': -4
}

s_drugs_19 = {
    'priors_4_5': 10,
'age_35_39': 9 ,
'prior_agg': 9 ,
'priors_1': 9 ,
'priors_2_3': 9 ,
'prior_weapons': 8 ,
'age_60_': 5 ,
'priors_count': 4 ,
'juv_other_1': 3 ,
'juv_other_2_': 3 ,
'priors_6_10': 3 ,
'age_50_54': 2 ,
'prior_battery': 2 ,
'juv_other_count': 1 ,
'age': -1 ,
'age_30_34': -3,
'juv_fel_count': -3,
'prior_assault': -5,
'prior_sexual': -6,
'juv_misd_count': -6,
'prior_public_order': -8,
'priors_11_': -8
}

# %%
df_sexual_train = pd.read_csv("compas-r-sexual-train.csv")
df_sexual_test = pd.read_csv("compas-r-sexual-test.csv")
df_sexual_train_y = df_sexual_train['is_sexual_recid']
df_sexual_test_y = df_sexual_test['is_sexual_recid']

rs_sexual_79 = {'prior_sexual': 4,
             'prior_driving': 2,
             'priors_4_5': 2,
             'priors_11_': 2,
             'prior_felony': -1,
             'juv_misd_count': -5}

rs_sexual_879 = {'prior_sexual': 4,
             'prior_driving': 1,
             'priors_4_5': 2,
             'priors_11_': 2,
             'prior_felony': -1,
             'juv_misd_count': -5}

rs_sexual_99 = {'prior_sexual': 4,
             'prior_driving': 1,
             'prior_battery': 1,
             'priors_11_': 2,
             'age_45_49': -2,
             'juv_misd_count': -5}

rs_sexual_113 = {'prior_sexual': 5,
             'prior_driving': 2,
             'prior_obstruction': 1,
            'priors_4_5': 1,
                 'prior_felony': -1,
             'juv_misd_count': -5,
             'age_45_49': -2}

rs_sexual_132 = {'prior_sexual': 3,
             'prior_driving': 2,
             'priors_11_': 2,
             'age_35_39': 1,
             'priors_4_5': 1,
             'prior_felony': -1,
             'juv_misd_count': -5}

rs_sexual_159 = {'prior_sexual': 4,
             'prior_driving': 2,
                 'priors_4_5': 2,
             'priors_11_': 2,
                 'prior_obstruction': 1,
                 'prior_battery': 1,
             'juv_misd_count': -5}

rs_sexual_199 = {'prior_sexual': 5,
             'prior_driving': 1,
             'prior_battery': 1,
                 'priors_4_5': 1,
             'priors_11_': 1,
             'age_45_49': -3,
             'juv_misd_count': -5}

rs_sexual_265 = {'prior_sexual': 5,
             'prior_drugs': -1,             
                 'priors_4_5': 1,
             'age_45_49': -3,
                 'prior_battery': -5,
             'juv_misd_count': -5}

rs_sexual_399 = {'prior_sexual': 5,
             'prior_driving': 2,             
                 'priors_4_5': 1,
                 'prior_felony': -2,
             'juv_misd_count': -3,
                'age_45_49': -3}

# %%
df_all_train = pd.read_csv("compas-features-nobinary-id-train.csv")
df_all_test = pd.read_csv("compas-features-nobinary-id-test.csv")
df_all_train_y = df_all_train['is_recid']
df_all_test_y = df_all_test['is_recid']

#  Pr(Y = +1) = 1/(1 + exp(-1 - score))
rs_all_067 = {
    'age_19_24': 1,
    'age_25_29': 1,
    'juv_other_1': 1,
    'juv_felony_1': 1,
    'priors_1': -1,
    'priors_2_3': -1
}

# Pr(Y = +1) = 1/(1 + exp(0 - score))
rs_all_1 = {
    'juv_other_1': 1,
    'age_55_59': -1,
    'age_60_': -1,
    'priors_1': -1,
    'priors_2_3': -1
}

# Pr(Y = +1) = 1/(1 + exp(-1 - score))
rs_all_15 = {
    'juv_other_1': 1,
    'prior_driving': 1,
    'priors_11_': 2,
    'priors_4_5': 1,
    'priors_6_10': 1
}

# Pr(Y = +1) = 1/(1 + exp(1 - score))
rs_all_3 = {
    'age_19_24': 1,
    'age_55_59': -1,
    'age_60_': -1,
    'priors_1': -1,
    'priors_2_3': -1
}

# Pr(Y = +1) = 1/(1 + exp(1 - score))   |
rs_all_344 = {
    'age_19_24': 1,
    'juv_misd_1': 1,
    'age_60_': -1,
    'priors_1': -1,
    'priors_2_3': -1
    
}

# Pr(Y = +1) = 1/(1 + exp(0 - score))
rs_all_4 = {
    'age_19_24': 1,
    'priors_11_': 2,
    'age_60_': -1,
    'priors_4_5': 1,
    'priors_6_10': 1
    
}

# Pr(Y = +1) = 1/(1 + exp(2 - score))
rs_all_471 = {
    'age_19_24': 1,
    'juv_felony_1': 1,
    'age_60_': -2,
    'priors_4_5': -1,
    'priors_1': -2,
    'priors_2_3': -2
}

# Pr(Y = +1) = 1/(1 + exp(1 - score))
rs_all_567 = {
    'age_19_24': 1,
    'age_25_29': 1,
    'age_30_34': 1,
    'age_35_39': 1,
    'priors_1': -1,
    'priors_2_3': -1
}

# Pr(Y = +1) = 1/(1 + exp(0 - score))
rs_all_7 = {
    'age_19_24': 2,
    'priors_11_': 2,
    'age_25_29': 1,
    'age_30_34': 1,
    'priors_4_5': 1,
    'priors_6_10': 1
}

# Pr(Y = +1) = 1/(1 + exp(1 - score))
rs_all_9 = {
    'juv_misd_1': 1,
    'priors_11_': 2,
    'age_55_59': -1,
    'age_60_': -1,
    'priors_4_5': 1,
    'priors_6_10': 1
    
}

# Pr(Y = +1) = 1/(1 + exp(3 - score))
rs_all_1233 = {
    'age_19_24': 1,
    'age_25_29': 1,
    'age_60_': -1,
    'priors_4_5': -1,
    'priors_6_10': -1,
    'priors_1': -1,
    'priors_2_3': -1
}

# Pr(Y = +1) = 1/(1 + exp(1 - score))
rs_all_19 = {
    'priors_6_10': 2,
    'age_19_24': 2,
    'priors_11_': 2,
    'age_25_29': 1,
    'age_30_34': 1,
    'priors_4_5': 1
}

# predict "is_recid = +1" if score > 1
s_all_067 = {
     'juv_misd_count': 1,
     'juv_misd_1': -1
}
#predict "is_recid = +1" if score > 1
s_all_1 = {
    'juv_felony_1': 2,
    'juv_misd_1': 2,
    'priors_11_': 2,
    'prior_weapons': -2,
    'priors_4_5': -2
}

#predict "is_recid = +1" if score > 1
s_all_15 = {
    'juv_misd_count': 4,
    'priors_4_5': 2,
    'priors_6_10': 2,
    'priors_11_': 2,
    'juv_other_1': 1,
    'juv_other_count': -1
}

# predict "is_recid = +1" if score > -7
s_all_267 = {
    'age_19_24': 8,
    'juv_felony_1': 4,
    'priors_4_5': 2,
    'priors_6_10': 2,
    'juv_misd_count': 2,
    'age_30_34': -2,
    'prior_assault': -2,
    'prior_driving': -2,
    'prior_sexual': -2,
    'prior_agg': -2,
    'age_35_39': -4,
    'age_55_59': -4,
    'prior_obstruction': -4,
    'prior_domestic': -4,
    'priors_2_3': -8,
    'priors_1': -10
}

# predict "is_recid = +1" if score > -3
s_all_4 = {
    'age_19_24': 4,
    'age_25_29': 2,
    'priors_1': 1,
    'age_50_54': -2,
    'juv_felony_2_': -2,
    'priors_2_3': -4
}

# predict "is_recid = +1" if score > 10
s_all_9 = {
    'juv_other_1': 10,
    'priors_1': 1,
    'prior_felony': -3,
    'age_40_44': -6
}

# %%
df_violent_train = pd.read_csv("compas-r-violent-train.csv")
df_violent_test = pd.read_csv("compas-r-violent-test.csv")
df_violent_train_y = df_violent_train['is_violent_recid']
df_violent_test_y = df_violent_test['is_violent_recid']

rs_violent_3 = {'prior_battery': 1,
                'juv_felony_1': 1,
             'age_45_49': -1,
             'age_60_': -2,
             'priors_1': -1,
             'priors_2_3': -1}

rs_violent_344 = {'age_19_24': 1,
                  'prior_battery': 1,
                  'priors_6_10': 1,
             'priors_4_5': 1,
            'priors_11_': 1,
              'age_45_49': -1,
             'age_60_': -2}

rs_violent_4 = {'priors_11_': 1,
             'prior_driving': 1,
             'priors_6_10': 1,
             'priors_4_5': 1}

rs_violent_471 = {'age_19_24': 1,
             'age_25_29': 1,
             'prior_battery': 1,
             'priors_1': -1,
             'priors_2_3': -1,
                 'age_60_': -2}

rs_violent_567 = {'age_19_24': 1,
             'age_25_29': 1,
             'age_35_39': 1,
                  'prior_battery': 1,
             'age_60_': -1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_violent_7 = {
            'prior_battery': 1,
            'juv_felony_1': 1,
             'priors_1': -1,
             'priors_2_3': -1,
            'age_60_': -2}

rs_violent_9 = {'age_19_24': 1,
             'age_45_49': -1,
             'age_50_54': -1,
                  'prior_battery': 1,
             'age_60_': -2,
             'priors_1': -1,
             'priors_2_3': -1}

rs_violent_1233 = {'age_19_24': 1,
             'age_25_29': 1,
                'prior_battery': 1,
             'priors_4_5': 1,
             'priors_6_10': 1,
                   'priors_11_': 1,
                  'age_60_': -1}


rs_violent_19 = {'priors_4_5': 1,
             'priors_6_10': 1,
                 'prior_battery': 1,
                 'juv_misd_2_': 1,
                 'juv_fel_count': 1,
                 'age_60_': -2,
                 'juv_felony_2_': -3}

# if score > -5
s_violent_1 = {'priors_count':2,
     			'age': -2,
     			 'juv_other_2_':-2}
# if score > 0
s_violent_3 = {'prior_battery': 4}

# >1
s_violent_344 = {'juv_misd_count': 1}

# >1
s_violent_4 = {'juv_felony_1': 2}

# 1
s_violent_471 = {'juv_misd_1': 2,
                'juv_misd_2_': 2}
# 1
s_violent_567 = {'priors_6_10': 2,
                    'juv_misd_count': 1,
                    'juv_misd_1': -1}

# if score > 3
s_violent_7 = {'juv_misd_2_': 10,
'prior_public_order': 6,
'juv_felony_1': 4,
'age_25_29': 2,
'age_30_34': 2,
'age_55_59': 2,
'prior_assault': 2,
'prior_obstruction': 2,
'prior_felony': 2,
'priors_6_10': 2,
'prior_property': -2,
'prior_domestic': -2,
'prior_agg': -4,
'priors_4_5': -4,
'prior_drugs': -6,
'juv_felony_2_': -10}
# 0
s_violent_9 = {'juv_felony_1': 4,
                    'age_55_59': 2, 
                    'prior_obstruction': 2,
                    'priors_4_5': 1,
                    'priors_6_10': 1,
                    'priors_1': -1,
                    'priors_2_3': -1,
                    'priors_11_': -1,
                    'juv_felony_2_': -2,
                    'age_50_54': -4,
                    'prior_driving': -4
}

# 3
s_violent_1233 = {
    'prior_battery': 10,
     			'prior_domestic': 10,
     			'age_19_24': 8,
     			'priors_4_5': 8,
     			'priors_6_10': 8,
     			'prior_violent': 6,
     			'prior_public_order': 6,
     			'priors_11_': 4,
     			'prior_drugs': -2,
     			'priors_2_3': -2,
     			'prior_sexual': -4,
     			'prior_agg': -4,
     			'age_50_54': -6,
     			'age_60_': -6
}

# -1
s_violent_19 = {
    'prior_felony': 6,
     			'age_30_34': 4,
     			'priors_6_10': 4,
     			'juv_fel_count': 4,
     			'age_50_54': 2,
     			'priors_2_3': 2,
     			'age_55_59': -2,
     			'prior_property': -2,
     			'prior_drugs': -4,
     			'prior_weapons': -4,
     			'age_60_': -10,
     			'prior_sexual': -10,
}

# > 9
s_violent_30 = {'age_35_39': 10,
     			'priors_6_10': 5,
     			'prior_battery': 4,
     			'juv_other_count': 3,
     			'age_30_34': 2,
     			'prior_property': 1,
     			'priors_2_3': 1,
     			'priors_count': -4,
     			'juv_misd_count': -6,
     			'juv_misd_1': -7,
     			'juv_other_1': -7,
     			'juv_fel_count': -7,
     			'prior_driving': -9,
     			'age_40_44': -10,
     			'age_45_49': -10,
     			'prior_drugs': -10,
     			'prior_obstruction': -10,
     			'juv_felony_2_': -10,
     			'priors_4_5': -10,
     			'priors_11_': -10,
    
}

# > -9
s_violent_50 = {'prior_assault': 10,
     			'prior_weapons': 8,
     			'age_19_24': 4,
     			'juv_felony_1': 4,
     			'juv_other_count': -1,
     			'prior_driving': -2,
     			'prior_drugs': -2,
     			'prior_public_order': -2,
     			'priors_1': -2,
     			'prior_violent': -4,
     			'age_45_49': -6,
     			'prior_property': -6,
     			'prior_agg': -6,
     			'age_60_': -8,
     			'prior_obstruction': -8
}

# score > -5
s_violent_200 = {
    'priors_6_10':6,
     			'prior_battery': 4,
     			'prior_felony': 4,
     			'priors_11_': 4,
     			'juv_fel_count': 3,
     			'age_19_24': 2,
     			'priors_2_3': 2,
     			'age_30_34': -2,
     			'age_60_': -2,
     			'prior_driving': -2,
     			'prior_drugs': -2,
     		'prior_property': -2,
     			'juv_misd_2_': -2,
     		'age_25_29': -4,
     			'age_40_44': -4,
     			'age_45_49': -4,
     			'age_50_54': -4,
     			'age_55_59': -4,
     			'prior_obstruction': -4,
     			'prior_assault': -6,
     			'juv_felony_2_': -8,
     			'prior_sexual': -10
}

# score < -1
s_violent_5000 = {
    'prior_drugs': 2,
     			'priors_count': 2,
     			'age_60_': -4,
     			'prior_sexual': -10
}

# %%
df_property_train = pd.read_csv("compas-r-property-train.csv")
df_property_test = pd.read_csv("compas-r-property-test.csv")
df_property_train_y = df_property_train['is_prop_recid']
df_property_test_y = df_property_test['is_prop_recid']

rs_property_3 = {'prior_property': 1,
                 'juv_other_1': 1,
             'age_35_39': -1,
             'prior_public_order': -1,
             'prior_domestic': -1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_property_344 = {'age_19_24': 1,
                   'prior_property': 1,
                   'prior_felony': 1,
                   'juv_misd_1': 1,
                   'juv_misd_count': -1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_property_4 = {'age_19_24': 1,
                   'prior_drugs': -1,
                   'prior_violent': -1,
             'priors_4_5': -1,
             'priors_6_10': -1,
                'priors_1': -2,
             'priors_2_3': -2}

rs_property_471 = {'age_19_24': 1,
             'prior_property': 1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_property_567 = {'age_19_24': 1,
             'prior_property': 1,
            'priors_11_': 1,
             'priors_1': -1,
             'priors_2_3': -1}


rs_property_7 = {'age_19_24': 1,
                 'priors_11_': 1,
             'priors_4_5': 1,
             'priors_6_10': 1,
             'prior_battery': -1,
                'prior_violent': -1,
                'prior_public_order': -1}

rs_property_9 = {'age_19_24': 1,
             'prior_weapons': 1,
                'prior_battery': -1,
                'prior_violent': -1,
                'prior_public_order': -1,
             'priors_1': -1,
             'priors_2_3': -1}

rs_property_1233 = {'age_19_24': 1,
                    'prior_property': 1,
                    'juv_other_1': 1,
                    'priors_4_5': 1,
             'priors_6_10': 1,
                'priors_11_': 1}


rs_property_19 = {'age_19_24': 1,
                  'priors_4_5': 1,
                  'priors_6_10': 1,
                'priors_11_': 1,
                  'prior_battery': -1,
                'prior_violent': -1,
                'prior_drugs': -1}
# predict "is_prop_recid = +1" if score > -10
s_property_3 = {

     'priors_11_': 10,
     			'juv_other_1': 7,
     			'juv_misd_count': -1,
     			'age': -1,
     			'prior_felony': -8
}

# predict "is_prop_recid = +1" if score > 10
s_property_344 = {
                'juv_other_2_': 6,
     			'priors_11_': 5,
     			'age_55_59': 4,
     			'prior_property': 4,
     			'age_45_49': 2,
     			'age_50_54': 2,
     			'juv_felony_2_': -2,
     			'priors_1': -1,
     			'prior_assault': -2,
     			'prior_felony': -2,
     			'juv_misd_count': -4,
}

# predict "is_prop_recid = +1" if score > 9
s_property_4 = {
                'juv_felony_2_': 6,
     			'age_30_34': 4,
     			'age_45_49': 4,
     			'priors_2_3': 4,
     			'age_35_39': 2,
     			'priors_4_5': 2,
     			'prior_driving': -2,
     			'prior_weapons': -4,
     			'juv_misd_1': -4
}

# predict "is_prop_recid = +1" if score > -8
s_property_471 = {
         	'prior_weapons': 9,
     			'priors_4_5': 7,
     			'juv_misd_1': 4,
     			'age_19_24': 3,
     			'juv_other_2_': 2,
     			'prior_property': 1,
     			'prior_felony': -1,
     			'juv_felony_2_': -1,
     			'age': -1,
     			'prior_battery': -2
}

# predict "is_prop_recid = +1" if score > 9
s_property_567 = {
            'juv_felony_2_': 10,
     			'prior_property': 6,
     			'juv_other_2_': 6,
     			'priors_11_': 6,
     			'prior_driving': 2,
     			'prior_agg': 2,
     			'prior_felony': 2,
     			'priors_6_10': 2,
     			'juv_fel_count': 2,
     			'age_45_49': -2,
     			'age_60_': -2,
     			'prior_drugs': -2,
     			'juv_felony_1': -2,
     			'age_30_34': -4,
     			'age_55_59': -4,
     			'prior_weapons': -4,
     			'priors_4_5': -4,
     			'age_19_24': -6,
     			'prior_obstruction': -8,
     			'juv_misd_2_': -8,
     			'juv_other_1': -8,
     			'age_25_29': -10,
     			'age_35_39': -10,
     			'prior_battery': -10
}

# predict "is_prop_recid = +1" if score > 1
s_property_7 = {
                'age_60_': 10,
     			'priors_4_5': 10,
     			'juv_felony_1': 8,
     			'priors_11_': 6,
     			'age_40_44': 4,
     			'prior_property': 4,
     			'juv_misd_1': 4,
     			'prior_felony': -2,
     			'juv_other_1': -2,
     			'juv_other_2_': -2,
     			'juv_other_count': -2,
     			'age_30_34': -4,
     			'prior_weapons': -4,
     			'prior_sexual': -4,
     			'juv_felony_2_': -4,
     			'age_45_49': -6,
     			'age_55_59': -6,
     			'prior_assault': -6,
     			'prior_obstruction': -6,
     			'prior_driving': -8,
     			'prior_public_order': -8,
     			'juv_misd_2_': -8,
     			'age_35_39': -10,
     			'age_50_54': -10,
     			'prior_drugs': -10,
     			'prior_domestic': -10,
     			'prior_agg': -10,
     			'prior_violent': -10,
     			'priors_1': -10,
     			'priors_2_3': -10
}

# predict "is_prop_recid = +1" if score > 1
s_property_9 = {   
                'age_19_24': 2,
     			'age_30_34': 2,
     			'prior_driving': 2,
     			'prior_property': 2,
     			'prior_weapons': 2,
     			'priors_1': -2,
     			'priors_2_3': -2,
     			'prior_public_order': -6
}

# predict "is_prop_recid = +1" if score > 1
s_property_1233 = {
                'priors_11_': 10,
     			'priors_6_10': 8,
     			'priors_4_5': 6,
     			'age_19_24': 4,
     			'age_30_34': -2,
     			'prior_assault': -2,
     			'prior_drugs': -2,
     			'prior_public_order': -2,
     			'age_35_39': -4
}

# predict "is_prop_recid = +1" if score > -1
s_property_19 = {
                'age_19_24': 2,
     			'priors_1': -2,
     			'priors_2_3': -2

}

# %%
df_po_train = pd.read_csv("compas-r-public-order-train.csv")
df_po_test = pd.read_csv("compas-r-public-order-test.csv")
df_po_train_y = df_po_train['is_po_recid']
df_po_test_y = df_po_test['is_po_recid']

# Pr(Y = +1) = 1/(1 + exp(-2 - score))
rs_po_3 = {
    'prior_public_order': 1,
    'juv_misd_2_': 1,
    'priors_6_10': 1,
    'age_45_49': -1,
    'age_50_54': -1,
    'age_60_': -1,
    'prior_weapons': -1
}

rs_po_344 = {
    'age_19_24': 1,
    'age_25_29': 1,
    'age_30_34': 1,
    'prior_drugs': 1,
    'priors_11_': 1,
    'priors_4_5': 1,
    'priors_6_10': 1
}

rs_po_4 = {
    'age_19_24': 1,
    'age_25_29': 1,
    'age_30_34': 1,
    'prior_drugs': 1,
    'priors_1': -1,
    'priors_2_3': -1
}

# Pr(Y = +1) = 1/(1 + exp(-2 - score))
rs_po_471 = {
    'prior_drugs': 1,
    'priors_11_': 1,
    'priors_4_5': 1,
    'priors_6_10': 1,
    'age_45_49': -1,
    'age_50_54': -1,
    'age_60_': -1
}

# Pr(Y = +1) = 1/(1 + exp(-1 - score))
rs_po_567 = {
    'age_25_29': 1,
    'prior_drugs': 1,
    'age_60_': -1,
    'priors_1': -1,
    'priors_2_3': -1
}

rs_po_7 = {
    'prior_drugs': 1,
    'juv_misd_2_': 1,
    'priors_6_10': 1,
    'age_45_49': -1,
    'age_50_54': -1,
    'age_60_': -1
}

rs_po_9 = {
        'prior_drugs': 1,
        'prior_domestic': 1,
    'age_40_44': -1,
    'age_50_54': -1,
    'age_60_': -1,
    'priors_1': -1,
    'priors_2_3': -1
}

rs_po_1233 = {
    'age_25_29': 1,
        'prior_drugs': 1,
    'priors_11_': 1,
    'priors_4_5': 1,
    'priors_6_10': 1,
    'age_50_54': -1,
    'age_60_': -1
}

rs_po_19 = {
    'age_19_24': 1,
    'age_25_29': 1,
    'prior_drugs': 1,
    'prior_domestic': 1,
    'age_50_54': -1,
    'priors_1': -1,
    'priors_2_3': -1
}

# predict "is_po_recid = +1" if score > -10
s_po_3 = {
'prior_drugs': 9 ,
'prior_agg': 9 ,
'prior_domestic': 6 ,
'prior_battery': 2 ,
'juv_misd_1': 2 ,
'priors_6_10': 2 ,
'age': -1 ,
'juv_other_2_': -4,
'priors_2_3': -4,
}

s_po_344 = {
    'juv_misd_2_': 8 ,
'age_30_34': 5 ,
'prior_driving': 4 ,
'prior_domestic': 4 ,
'prior_public_order': 4 ,
'prior_violent': 2 ,
'juv_felony_1': 2 ,
'priors_11_': 2 ,
'juv_misd_count': -1 ,
'prior_felony': -2,
'juv_felony_2_': -2,
'age_25_29': -3,
'age_35_39': -3,
'prior_obstruction': -3,
'prior_weapons': -4,
'juv_other_count': -5
}

s_po_4 = {
    #predict "is_po_recid = +1" if score > 7
'prior_battery': 2 ,
'prior_weapons': 2 ,
'prior_domestic': 2 ,
'prior_violent': 2 ,
'prior_felony': 2 ,
'juv_felony_1': 2 ,
'juv_other_count': -1 ,
'age_35_39': -2,
'age_45_49': -2,
'age_50_54': -2,
'priors_2_3': -2,
}

# predict "is_po_recid = +1" if score > 9
s_po_471 = {  
'juv_misd_2_': 8 ,
'prior_drugs': 6 ,
'prior_weapons': 6 ,
'juv_other_1': 5 ,
'prior_felony': 2 ,
'juv_other_count': -1 ,
'priors_4_5': -2,
'prior_public_order': -4,
'priors_2_3': -4,
'priors_11_': -4,
'age_19_24': -6
}

# predict "is_po_recid = +1" if score > -10
s_po_567= {
    'prior_battery': 10,
'priors_6_10': 9 ,
'priors_count': 7 ,
'age_19_24': 2 ,
'age': -1,
'id': -1 ,
'age_30_34': -8,
'prior_felony': -10
}

# predict "is_po_recid = +1" if score > 4
s_po_7 = {
    'prior_assault': 10,
'prior_driving': 10,
'prior_domestic': 10,
'prior_felony': 10,
'juv_felony_1': 10,
'priors_4_5': 10,
'priors_6_10': 10,
'priors_11_': 10,
'age_35_39': 9 ,
'juv_other_1': 9 ,
'priors_2_3': 9 ,
'prior_weapons': 8 ,
'prior_drugs': 7 ,
'prior_violent': 6 ,
'prior_property': 5 ,
'juv_misd_2_': 3 ,
'priors_count': 2 ,
'age_25_29': 1 ,
'juv_fel_count': -1 ,
'age': -2,
'juv_misd_1': -5,
'prior_public_order': -8,
'juv_other_2_': -9
}

# predict "is_po_recid = +1" if score > 8
s_po_9 = {
    'age_19_24': 6 ,
'priors_6_10': 5 ,
'age_25_29': 4 ,
'age_35_39': 2 ,
'age_40_44': 2 ,
'prior_drugs': 2 ,
'priors_1': 1,
'priors_2_3': -1 ,
'priors_4_5': -1 ,
'prior_agg': -2,
'prior_public_order': -2,
'juv_felony_1': -2,
'juv_misd_2_': -2,
'juv_fel_count': -2,
'prior_battery': -4,
'prior_obstruction': -4
}

s_po_1233 = {
    'prior_sexual': 10,
'age_25_29': 9 ,
'prior_battery': 8 ,
'juv_misd_2_': 8 ,
'prior_drugs': 6 ,
'age_19_24': 5 ,
'juv_felony_1': 4 ,
'juv_other_2_': 4 ,
'age_35_39': 3 ,
'prior_driving': 2 ,
'age_60_': -1 ,
'prior_felony': -2,
'prior_agg': -4,
'juv_other_1': -4,
'priors_6_10': -4,
'priors_11_': -4,
'juv_fel_count': -4,
'age_30_34': -5,
'age_40_44': -5,
'age_45_49': -5,
'age_50_54': -5,
'age_55_59': -5,
'prior_obstruction': -6,
'priors_4_5': -6,
'priors_2_3': -8
}

# predict "is_po_recid = +1" if score > -10
s_po_19 = {
    'age_35_39': 10,
'priors_2_3': 10,
'priors_4_5': 6 ,
'prior_drugs': 5 ,
'priors_1': 5 ,
'age_30_34': 3 ,
'prior_battery': 3 ,
'prior_felony': 3 ,
'age_55_59': 2 ,
'priors_6_10': 2 ,
'priors_count': 2 ,
'prior_driving': 1 ,
'juv_misd_2_': 1 ,
'prior_property': -1 ,
'juv_felony_2_': -1,
'juv_other_1': -1 ,
'age': -1 ,
'age_19_24': -2,
'age_40_44': -3,
'priors_11_': -3,
'prior_sexual': -5,
'age_45_49': -7
}

# %%
coef_list_d_rs = [rs_drugs_3,
         rs_drugs_344,
         rs_drugs_4,
         rs_drugs_471,
         rs_drugs_567,
         rs_drugs_7,
         rs_drugs_9,
         rs_drugs_1233,
         rs_drugs_19]

coef_list_d_s = [s_drugs_3,
         s_drugs_344,
         s_drugs_4,
         s_drugs_471,
         s_drugs_567,
         s_drugs_7,
         s_drugs_9,
         s_drugs_1233,
         s_drugs_19]

coef_list_s = [rs_sexual_79,
         rs_sexual_879,
         rs_sexual_99,
         rs_sexual_113,
         rs_sexual_132,
         rs_sexual_159,
         rs_sexual_199,
         rs_sexual_265,
         rs_sexual_399]

coef_list_v = [rs_violent_3,
         rs_violent_344,
         rs_violent_4,
         rs_violent_471,
         rs_violent_567,
         rs_violent_7,
         rs_violent_9,
         rs_violent_1233,
         rs_violent_19]

coef_list_v_s = [s_violent_1, s_violent_3,
         s_violent_344,
         s_violent_4,
         s_violent_471,
         s_violent_567,
         s_violent_7,
         s_violent_9,
         s_violent_1233,
         s_violent_19,
                s_violent_30,
         s_violent_50, s_violent_200, s_violent_5000]

coef_list_pr = [rs_property_3,
         rs_property_344,
         rs_property_4,
         rs_property_471,
         rs_property_567,
         rs_property_7,
         rs_property_9,
         rs_property_1233,
         rs_property_19]

coef_list_pr_s = [s_property_3,
         s_property_344,
         s_property_4,
         s_property_471,
         s_property_567,
         s_property_7,
         s_property_9,
         s_property_1233,
         s_property_19]

coef_list_all_rs = [
    rs_all_067,
    rs_all_1,
    rs_all_15,
    rs_all_3,
    rs_all_4,
    rs_all_9,
]

coef_list_all_s = [
    s_all_067,
    s_all_1,
    s_all_15,
    s_all_267,
    s_all_4,
    s_all_9,
]

coef_list_po_rs = [
    rs_po_3,
    rs_po_344,
    rs_po_4,
    rs_po_471,
    rs_po_567,
    rs_po_7,
    rs_po_9,
    rs_po_1233,
    rs_po_19
]

coef_list_po_s = [
    s_po_3,
    s_po_344,
    s_po_4,
    s_po_471,
    s_po_567,
    s_po_7,
    s_po_9,
    s_po_1233,
    s_po_19
]

# %%
df_test_y = df_violent_test_y
type(df_test_y)
# Out:
# pandas.core.series.Series

# %%
df_test = df_all_test
df_test_y = df_all_test_y
coef_list = coef_list_all_s
#thresholds = [-5, 0, 1,1,1,1,3,0,3,-1, 9, -9, -5, -1]

#tprs = []
#fprs = []
for i, coefs in enumerate(coef_list):
    #print 'LIST', coef_list.index(coefs)
    scores = np.zeros((df_test.shape[0]))
    COMPONENTS = coefs
    for c in COMPONENTS:
        scores += df_test[c]*COMPONENTS[c]
    y_true = pd.Series.as_matrix(df_test_y)

    new_scores = np.reshape(scores, (-1, 1))
    new_y_true = np.reshape(y_true, (-1, 1))

    all_y = np.concatenate((new_y_true, new_scores), axis=1)

    np.savetxt('all_y_s_all_' + str(i)+'.csv',all_y)

# %%
df_test = df_po_test
df_test_y = df_po_test_y
coef_list = coef_list_po_s
# violent thresholds = [-5, 0, 1,1,1,1,3,0,3,-1, 9, -9, -5, -1]
# property
#thresholds = [-10, 10, 9, -8, 9, 1, 1, 1, -1]

# general thresholds
thresholds = [1,1,1,-7,-3,10]

tp = 0
fp = 0
tn = 0
fn = 0

tprs = []
fprs = []
for i, coefs in enumerate(coef_list):
    print '***************************'
    print 'LIST', coef_list.index(coefs)
    scores = np.zeros((df_test.shape[0]))
    COMPONENTS = coefs
    for c in COMPONENTS:
        scores += df_test[c]*COMPONENTS[c]
    y_true = pd.Series.as_matrix(df_test_y)

    new_scores = np.reshape(scores, (-1, 1))
    new_y_true = np.reshape(y_true, (-1, 1))

    all_y = np.concatenate((new_y_true, new_scores), axis=1)
    
    np.savetxt('all_y_s_drugs_' + str(i)+'.csv',all_y)
    '''
    for j, score in enumerate(scores):
        if score > thresholds[i]:
            guess = 1
        else:
            guess = 0
        ans = df_test_y[j]
        
        if ans + guess == 2:
            tp += 1
        elif ans + guess == 0:
            tn += 1
        elif ans == 1:
            fn += 1
        else:
            fp += 1
    tpr = float(tp)/float(tp+fn)
    print 'tpr', tpr
    tprs.append(tpr)
    
    fpr = float(fp)/float(fp+tn)
    print 'fpr', fpr
    fprs.append(fpr)
    

print tprs
print fprs
'''
# Out:
# ***************************
# LIST 0
# ***************************
# LIST 1
# ***************************
# LIST 2
# ***************************
# LIST 3
# ***************************
# LIST 4
# ***************************
# LIST 5
# ***************************
# LIST 6
# ***************************
# LIST 7
# ***************************
# LIST 8

# %%
df_test = df_all_test
df_test_y = df_all_test_y
SLIM_COMPARE = True

for coefs in coef_list_all_rs:
    print '***************************'
    print 'LIST', coef_list_all_rs.index(coefs)
    scores = np.zeros((df_test.shape[0]))
    COMPONENTS = coefs
    for c in COMPONENTS:
        scores += df_test[c]*COMPONENTS[c]
    scores_unique = np.asarray(sorted(scores.unique()))
    probs = 1/(1+np.exp(-1-scores))
    probs_unique = 1/(1+np.exp(-1-scores_unique))
    
    if SLIM_COMPARE:
        BOUNDS = [0]
        BOUNDS = np.append(BOUNDS, .3)
        BOUNDS = np.append(BOUNDS, .4)
        BOUNDS = np.append(BOUNDS, .5)
        BOUNDS = np.append(BOUNDS, .6)
        BOUNDS = np.append(BOUNDS, .7)
        BOUNDS = np.append(BOUNDS, .8)
        BOUNDS = np.append(BOUNDS, .9)
        BOUNDS = np.append(BOUNDS, 1)
    else:
        BOUNDS = probs_unique
    
    
    tprs = []
    #print type(tprs)
    fprs = []
    for ind, BOUND in enumerate(BOUNDS):
        
        total = 0
        correct = 0
        df_y = df_test_y
        tp = 0
        fp = 0
        tn = 0
        fn = 0
        #print type(tprs)
        
        for i in range(len(list(df_y))):
            ans = df_y[i]
            if probs[i] > BOUND:
                guess = 1
            else:
                guess = 0
            if ans + guess == 2:
                tp += 1
            elif ans + guess == 0:
                tn += 1
            elif ans == 1: # guess must be 0
                fn += 1
            else:
                fp += 1

            total +=1
        #print type(tprs)
        print '-------------------'
        print 'BOUND:', BOUND
        if ind < len(scores_unique):
            print 'scores:', scores_unique[ind]
        tpr = float(tp)/float(tp+fn)
        fpr = float(fp)/float(fp+tn)
        print type(tprs)
        print 'tpr', tpr
        print 'fpr', fpr
        tprs.append(tpr)
        fprs.append(fpr)     
    print tprs
    print fprs
# Out:
# ***************************
# LIST 0
# -------------------
# BOUND: 0.0
# scores: -1.0
# <type 'list'>
# tpr 1.0
# fpr 1.0
# -------------------
# BOUND: 0.3
# scores: 0.0
# <type 'list'>
# tpr 1.0
# fpr 1.0
# -------------------
# BOUND: 0.4
# scores: 1.0
# <type 'list'>
# tpr 1.0
# fpr 1.0
# -------------------
# BOUND: 0.5
# scores: 2.0
# <type 'list'>
# tpr 0.796157059315
# fpr 0.546014790468
# -------------------
# BOUND: 0.6
# scores: 3.0
# <type 'list'>
# tpr 0.796157059315
# fpr 0.546014790468
# -------------------
# BOUND: 0.7
# <type 'list'>
# tpr 0.796157059315
# fpr 0.546014790468
# -------------------
# BOUND: 0.8
# <type 'list'>
# tpr 0.255639097744
# fpr 0.0846343467543
# -------------------
# BOUND: 0.9
# <type 'list'>
# tpr 0.0426065162907
# fpr 0.00739523418242
# -------------------
# BOUND: 1.0
# <type 'list'>
# tpr 0.0
# fpr 0.0
# [1.0, 1.0, 1.0, 0.7961570593149541, 0.7961570593149541, 0.7961570593149541, 0.2556390977443609, 0.042606516290726815, 0.0]
# ...

# %% [markdown]
# components2: BOUND = .74 to .88, score = 0.687630646187
# components1: same
